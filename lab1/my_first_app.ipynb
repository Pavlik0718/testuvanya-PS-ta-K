# %%
from datetime import datetime

name = "Pavlo"  # Змініть на своє!
location = "Warssaw"  # Змініть на своє!

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")

# %% [markdown]
# # Моя перша програма на Python
#
# ## Опис програми:
# Ця програма виконує наступне:
# 1. Виводить ім'я програміста
# 2. Показує час запуску
# 3. Хвалить моє улюблене місто
#
# ## Використані бібліотеки:
# - `datetime` - для роботи з часом
# - Вбудована функція `print()` - для виводу
