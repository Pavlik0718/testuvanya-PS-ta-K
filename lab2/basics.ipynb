# %% [markdown]
# # Основи Python
# ## 1. Типи даних
# Тут вивчаємо основні типи даних у Python

# %%
a = "Привіт"
b = 100
print(a, b)
print(type(a), type(b))
# Out:
# Привіт 100
# <class 'str'> <class 'int'>

# %% [markdown]
# ## 2. Цикли
# Вивчаємо цикли for та while

# %%
for i in range(3):
    print(f"Крок {i}")
# Out:
# Крок 0
# Крок 1
# Крок 2
